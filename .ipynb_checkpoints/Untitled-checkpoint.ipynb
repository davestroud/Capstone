# %%
import pandas as pd
frequency = pd.read_csv('aws_instance_freq.csv', low_memory=False)

# %%
frequency
# Out:
#      Instance Type  vCPU  Memory GiB Savings over On-Demand*  \
# 0         m5.large     2        8.00                     79%
# 1         t3.micro     2        1.00                     70%
# 2    r5ad.12xlarge    48      384.00                      0%
# 3     r5a.12xlarge    48      384.00                     69%
# 4         r5.large     2       16.00                     83%
# 5     c5d.18xlarge    72      144.00                     78%
# 6     r5ad.2xlarge     8       64.00                     67%
# 7       c4.4xlarge    16       30.00                     82%
# 8    m5ad.24xlarge    96      384.00                     28%
# 9       c4.2xlarge     8       15.00                     82%
# 10       c5.xlarge     4        8.00                     78%
# 11      c5.4xlarge    16       32.00                     78%
# 12        m4.large     2        8.00                     81%
# 13      i3.4xlarge    16      122.00                     70%
# ...
